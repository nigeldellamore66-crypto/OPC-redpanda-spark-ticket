# %%
import pandas as pd

pd.set_option("display.max_columns", None)   # toutes les colonnes
pd.set_option("display.max_rows", 200)       # plus de lignes
pd.set_option("display.width", 2000)         # largeur console
pd.set_option("display.max_colwidth", None)  # colonnes texte non tronquées

# %%
df = pd.read_parquet("output/parquet/client-tickets")

# %%
print(df.head(10))
# Out:
#                               ticket_id  client_id                        created_at                           demande type_demande  priorite support_team
# 0  9ff0a542-cdc9-4887-9e52-4d7d6ade8355       4396  2026-03-03T22:31:41.015439+00:00             Erreur sur la facture  facturation     haute       Team B
# 1  40dde0a6-eaa2-4a96-945c-0e461f1f99e4       7917  2026-03-03T22:31:43.015892+00:00    Impossible d'accéder au compte  facturation  critique       Team B
# 2  61c707bc-ed3d-4143-8ade-a49c51799358       1004  2026-03-03T22:31:45.016520+00:00  Problème de connexion au service  facturation     basse       Team B
# 3  ea989f8e-3447-4b60-8a5f-7e6d61ae3562       2410  2026-03-03T22:31:47.016893+00:00            Application qui plante    technique   moyenne       Team C
# 4  a2adc122-28ac-4c9f-a42c-d1919164e221       7692  2026-03-03T22:31:49.017303+00:00     Demande d'information produit    technique   moyenne       Team C
# ...

# %%
print(df.shape)
# Out:
# (129, 7)

# %%
print(df.columns)
# Out:
# Index(['ticket_id', 'client_id', 'created_at', 'demande', 'type_demande', 'priorite', 'support_team'], dtype='str')

# %%
print(df["type_demande"].value_counts())
# Out:
# type_demande
# facturation    37
# technique      36
# incident       34
# information    22
# Name: count, dtype: int64

# %%
print(df.isna().sum())
# Out:
# ticket_id       0
# client_id       0
# created_at      0
# demande         0
# type_demande    0
# priorite        0
# support_team    0
# dtype: int64
